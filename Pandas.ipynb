# %% [markdown]
# # Pandas

# %% [markdown]
# References: https://www.kaggle.com/rajacsp/pandas-cheatsheet-125-exercises https://www.kaggle.com/grroverpr/pandas-cheatsheet
#             https://www.kaggle.com/lavanyashukla01/pandas-numpy-python-cheatsheet https://www.kaggle.com/learn/pandas https://learn.datacamp.com/courses/data-manipulation-with-pandas https://www.stats.govt.nz/large-datasets/csv-files-for-download/

# %% [markdown]
# The Pandas library is built on NumPy and provides easy-to-use data structures and data analysis tools for the Python programming language.

# %% [markdown]
# ### Pandas Data Structures
# 1.Series: A one-dimensional labeled array,capable of holding any data type.One of the main differences between Pandas Series and NumPy ndarrays is that you can assign an index label to each element in the Pandas Series.
#
# pd.Series(data, index)
#
# 2.Dataframe:Pandas DataFrames are two-dimensional data structures with labeled rows and columns, that can hold many data types.

# %% [markdown]
# ### Input/Output

# %% [markdown]
# ......

# %% [markdown]
# ### Different ways of creating DataFrame

# %% [markdown]
# .............

# %%
import pandas as pd
df=pd.read_csv('enterprise-survey.csv')
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %% [markdown]
# .head() returns the first few(mostly 5)

# %%
df.tail() #displays last few rows of the dataframe.
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 32440  Food product manufacturing  Percentage           H37
# 32441  Food product manufacturing  Percentage           H38
# 32442  Food product manufacturing  Percentage           H39
# 32443  Food product manufacturing  Percentage           H40
# 32444  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 32440                          Quick ratio  Financial ratios    52
# 32441  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32445 entries, 0 to 32444
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         32445 non-null  int64
#  1   Industry_aggregation_NZSIOC  32445 non-null  object
#  2   Industry_code_NZSIOC         32445 non-null  object
#  3   Industry_name_NZSIOC         32445 non-null  object
#  4   Units                        32445 non-null  object
#  5   Variable_code                32445 non-null  object
#  6   Variable_name                32445 non-null  object
#  7   Variable_category            32445 non-null  object
#  8   Value                        32445 non-null  object
#  9   Industry_code_ANZSIC06       32445 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB

# %% [markdown]
# .info() shows info on each of the columns such as data types and missing values.

# %%
df.shape #rows,column
# Out:
# (32445, 10)

# %%
df.describe() #calculates a few summary statistics for each column
# Out:
#                Year
# count  32445.000000
# mean    2016.000000
# std        2.000031
# min     2013.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2018.000000
# max     2019.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32445, step=1)

# %%
df.columns #gives all the column names
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df.values #df.values returns a numpy array with the underlying data of the DataFrame, without any index or columns names.
# Out:
# array([[2019, 'Level 1', '99999', ..., 'Financial performance',
#         '728,239',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2019, 'Level 1', '99999', ..., 'Financial performance',
#         '643,809',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        [2019, 'Level 1', '99999', ..., 'Financial performance', '62,924',
#         'ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)'],
#        ...,
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '12',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
#        [2013, 'Level 3', 'ZZ11', ..., 'Financial ratios', '5',
#         'ANZSIC06 groups C111, C112, C113, C114, C115, C116, C117, C118, and C119'],
# ...

# %% [markdown]
# ### Sorting and subsetting

# %%
df.sort_index() #sort the dataframe through the index.
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.sort_values('Industry_code_NZSIOC',ascending=True)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 27835  2013                     Level 1                99999
# 27836  2013                     Level 1                99999
# 27837  2013                     Level 1                99999
# 27838  2013                     Level 1                99999
# ...     ...                         ...                  ...
# 23172  2015                     Level 3                 ZZ11
# 23171  2015                     Level 3                 ZZ11
# 23170  2015                     Level 3                 ZZ11
# 4631   2019                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 27835              All industries             Dollars           H35
# ...

# %%
df.sort_values(['Industry_code_NZSIOC','Year'],ascending=False) #sorting by multiple values
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 4599   2019                     Level 3                 ZZ11
# 4600   2019                     Level 3                 ZZ11
# 4601   2019                     Level 3                 ZZ11
# 4602   2019                     Level 3                 ZZ11
# 4603   2019                     Level 3                 ZZ11
# ...     ...                         ...                  ...
# 27836  2013                     Level 1                99999
# 27837  2013                     Level 1                99999
# 27838  2013                     Level 1                99999
# 27839  2013                     Level 1                99999
# 27840  2013                     Level 1                99999
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 4599   Food Product Manufacturing  Dollars (millions)           H01
# 4600   Food Product Manufacturing  Dollars (millions)           H02
# ...

# %%
df.sort_values('Year',ascending=True)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32444  2013                     Level 3                 ZZ11
# 29349  2013                     Level 4                CC822
# 29350  2013                     Level 4                CC822
# 29351  2013                     Level 4                CC822
# 29352  2013                     Level 4                CC822
# ...     ...                         ...                  ...
# 3092   2019                     Level 1                   KK
# 3093   2019                     Level 1                   KK
# 3094   2019                     Level 1                   KK
# 3042   2019                     Level 3                 JJ11
# 0      2019                     Level 1                99999
#
#                    Industry_name_NZSIOC               Units Variable_code  \
# 32444        Food product manufacturing          Percentage           H41
# 29349           Machinery Manufacturing  Dollars (millions)           H09
# ...

# %%
df.sort_values(['Industry_code_NZSIOC','Year'],ascending=[False,True]) #sort first column by descending order and Year by ascending order.
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 32409  2013                     Level 3                 ZZ11
# 32410  2013                     Level 3                 ZZ11
# 32411  2013                     Level 3                 ZZ11
# 32412  2013                     Level 3                 ZZ11
# 32413  2013                     Level 3                 ZZ11
# ...     ...                         ...                  ...
# 26     2019                     Level 1                99999
# 27     2019                     Level 1                99999
# 28     2019                     Level 1                99999
# 29     2019                     Level 1                99999
# 30     2019                     Level 1                99999
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 32409  Food product manufacturing  Dollars (millions)           H01
# 32410  Food product manufacturing  Dollars (millions)           H02
# ...

# %%
#Subsetting columns
df['Year']
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32440    2013
# 32441    2013
# 32442    2013
# 32443    2013
# 32444    2013
# Name: Year, Length: 32445, dtype: int64

# %%
df.Year
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32440    2013
# 32441    2013
# 32442    2013
# 32443    2013
# 32444    2013
# Name: Year, Length: 32445, dtype: int64

# %%
columns_selected=['Year','Units']
df[columns_selected]
# Out:
#        Year               Units
# 0      2019  Dollars (millions)
# 1      2019  Dollars (millions)
# 2      2019  Dollars (millions)
# 3      2019  Dollars (millions)
# 4      2019  Dollars (millions)
# ...     ...                 ...
# 32440  2013          Percentage
# 32441  2013          Percentage
# 32442  2013          Percentage
# 32443  2013          Percentage
# 32444  2013          Percentage
#
# [32445 rows x 2 columns]

# %%
df[['Year','Units']]
# Out:
#        Year               Units
# 0      2019  Dollars (millions)
# 1      2019  Dollars (millions)
# 2      2019  Dollars (millions)
# 3      2019  Dollars (millions)
# 4      2019  Dollars (millions)
# ...     ...                 ...
# 32440  2013          Percentage
# 32441  2013          Percentage
# 32442  2013          Percentage
# 32443  2013          Percentage
# 32444  2013          Percentage
#
# [32445 rows x 2 columns]

# %%
#Subsetting rows
df[df['Year']>2018]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     2019                     Level 1                99999
# 1     2019                     Level 1                99999
# 2     2019                     Level 1                99999
# 3     2019                     Level 1                99999
# 4     2019                     Level 1                99999
# ...    ...                         ...                  ...
# 4630  2019                     Level 3                 ZZ11
# 4631  2019                     Level 3                 ZZ11
# 4632  2019                     Level 3                 ZZ11
# 4633  2019                     Level 3                 ZZ11
# 4634  2019                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 0                 All industries  Dollars (millions)           H01
# 1                 All industries  Dollars (millions)           H04
# ...

# %%
df[df['Units']=='Percentage']
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 26     2019                     Level 1                99999
# 27     2019                     Level 1                99999
# 28     2019                     Level 1                99999
# 29     2019                     Level 1                99999
# 30     2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 26                 All industries  Percentage           H36
# 27                 All industries  Percentage           H37
# ...

# %%
df['Year'][df['Units']=='Dollars (millions)']
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 32432    2013
# 32433    2013
# 32434    2013
# 32435    2013
# 32436    2013
# Name: Year, Length: 25508, dtype: int64

# %%
df[['Year','Industry_code_NZSIOC','Units']][df['Units']=='Dollars (millions)']
# Out:
#        Year Industry_code_NZSIOC               Units
# 0      2019                99999  Dollars (millions)
# 1      2019                99999  Dollars (millions)
# 2      2019                99999  Dollars (millions)
# 3      2019                99999  Dollars (millions)
# 4      2019                99999  Dollars (millions)
# ...     ...                  ...                 ...
# 32432  2013                 ZZ11  Dollars (millions)
# 32433  2013                 ZZ11  Dollars (millions)
# 32434  2013                 ZZ11  Dollars (millions)
# 32435  2013                 ZZ11  Dollars (millions)
# 32436  2013                 ZZ11  Dollars (millions)
#
# [25508 rows x 3 columns]

# %%
df[(df['Year']>2018)& (df['Units']=='Percentage')]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 26    2019                     Level 1                99999
# 27    2019                     Level 1                99999
# 28    2019                     Level 1                99999
# 29    2019                     Level 1                99999
# 30    2019                     Level 1                99999
# ...    ...                         ...                  ...
# 4630  2019                     Level 3                 ZZ11
# 4631  2019                     Level 3                 ZZ11
# 4632  2019                     Level 3                 ZZ11
# 4633  2019                     Level 3                 ZZ11
# 4634  2019                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC       Units Variable_code  \
# 26                All industries  Percentage           H36
# 27                All industries  Percentage           H37
# 28                All industries  Percentage           H39
# ...

# %%
df[(df['Year']>2018)| (df['Units']=='Percentage')] #Logical OR
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
#Subsetting using isin(),categorical values
year_2019=df['Year'].isin([2019])
year_2019
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32440    False
# 32441    False
# 32442    False
# 32443    False
# 32444    False
# Name: Year, Length: 32445, dtype: bool

# %%
df[year_2019]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     2019                     Level 1                99999
# 1     2019                     Level 1                99999
# 2     2019                     Level 1                99999
# 3     2019                     Level 1                99999
# 4     2019                     Level 1                99999
# ...    ...                         ...                  ...
# 4630  2019                     Level 3                 ZZ11
# 4631  2019                     Level 3                 ZZ11
# 4632  2019                     Level 3                 ZZ11
# 4633  2019                     Level 3                 ZZ11
# 4634  2019                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 0                 All industries  Dollars (millions)           H01
# 1                 All industries  Dollars (millions)           H04
# ...

# %%
df[df['Industry_aggregation_NZSIOC'].isin(['Level1','Level 3'])]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 62     2019                     Level 3                 AA11
# 63     2019                     Level 3                 AA11
# 64     2019                     Level 3                 AA11
# 65     2019                     Level 3                 AA11
# 66     2019                     Level 3                 AA11
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#                  Industry_name_NZSIOC               Units Variable_code  \
# 62     Horticulture and Fruit Growing  Dollars (millions)           H01
# 63     Horticulture and Fruit Growing  Dollars (millions)           H04
# ...

# %% [markdown]
# ### Adding a new column to a dataframe

# %%
df['Day']=df.Value*2
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %% [markdown]
# <b>We can also create a new column by using a list, df.insert(index,'Columnname',value),df.assign(columnname='value')</b>

# %% [markdown]
# ### Summary Statistics

# %%
df.Year.min()
# Out:
# 2013

# %%
df.Year.max()
# Out:
# 2019

# %%
df.Year.agg(min)
# Out:
# 2013

# %%
import numpy as np
agg_func=[min,max,sum]
df[['Value','Industry_code_NZSIOC']].agg(agg_func)
# Out:
#                                                  Value  \
# min                                                 -1
# max                                                  S
# sum  728,239643,80962,92421,505634,71035,2507,45820...
#
#                                   Industry_code_NZSIOC
# min                                              99999
# max                                               ZZ11
# sum  9999999999999999999999999999999999999999999999...

# %%
#cumulative statistics
df.Value.cumsum()
# Out:
# 0                                                  728,239
# 1                                           728,239643,809
# 2                                     728,239643,80962,924
# 3                               728,239643,80962,92421,505
# 4                        728,239643,80962,92421,505634,710
#                                ...
# 32440    728,239643,80962,92421,505634,71035,2507,45820...
# 32441    728,239643,80962,92421,505634,71035,2507,45820...
# 32442    728,239643,80962,92421,505634,71035,2507,45820...
# 32443    728,239643,80962,92421,505634,71035,2507,45820...
# 32444    728,239643,80962,92421,505634,71035,2507,45820...
# Name: Value, Length: 32445, dtype: object

# %%
df.Value.cummin()
# Out:
# 0        728,239
# 1        643,809
# 2         62,924
# 3         21,505
# 4         21,505
#           ...
# 32440         -1
# 32441         -1
# 32442         -1
# 32443         -1
# 32444         -1
# Name: Value, Length: 32445, dtype: object

# %%
#df.Year.drop_duplicates()

# %%
df.Year.value_counts()
# Out:
# 2015    4635
# 2014    4635
# 2013    4635
# 2019    4635
# 2018    4635
# 2017    4635
# 2016    4635
# Name: Year, dtype: int64

# %%
numbers=[2,6,8,1]
for index,num in enumerate(numbers,7):
    print(index,num)
# Out:
# 7 2
# 8 6
# 9 8
# 10 1
